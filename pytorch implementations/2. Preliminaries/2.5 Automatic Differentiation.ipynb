# %%
import torch

x = torch.arange(4.0, requires_grad=True)
x
# Out:
# tensor([0., 1., 2., 3.], requires_grad=True)

# %%
x.requires_grad_(True)
x.grad

# %%
y = 2*x@x
y
# Out:
# tensor(28., grad_fn=<DotBackward0>)

# %%
y.backward()
x.grad
# Out:
# tensor([ 0.,  4.,  8., 12.])

# %%
x.grad == 4*x
# Out:
# tensor([True, True, True, True])

# %%
x.grad.zero_()
y = x.sum()
y.backward()
x.grad
# Out:
# tensor([1., 1., 1., 1.])

# %% [markdown]
# Backward for Non-Scalar Variables

# %%
x.grad.zero_()
y = x * x
y.backward(gradient=torch.ones(len(y)))  # Faster: y.sum().backward()
x.grad
y.sum()
# Out:
# tensor(14., grad_fn=<SumBackward0>)

# %% [markdown]
# \begin{equation}
#     \nabla y \cdot (1, 1, 1, ..., 1) =  \sum_{i=1}^{n} \frac{\partial y}{\partial x_i}
# \end{equation}

# %% [markdown]
# Detaching Computation

# %%
x.grad.zero_()
y = x * x
u = y.detach() # detaches u from the computational graph
u.requires_grad = True
z = u * x

z.sum().backward()
x.grad, u.grad # yields x^2, # yields x
# Out:
# (tensor([0., 1., 4., 9.]), tensor([0., 1., 2., 3.]))

# %% [markdown]
# Note that while this procedure detaches y’s ancestors from the graph leading to z, the computational graph leading to y persists and thus we can calculate the gradient of y with respect to x.

# %%
x.grad.zero_()
y.sum().backward()
x.grad
# yields 3x^2
# Out:
# tensor([0., 2., 4., 6.])

# %% [markdown]
# Gradients & Python Control Flow

# %%
def f(a):
    b = a * 2
    while b.norm() < 1000:
        b = b * 2
    if b.sum() > 0:
        c = b
    else:
        c = 100 * b
    return c

# %%
a = torch.randn(size=(), requires_grad=True) # size = () denotes a scalar tensor whereas size = (1) would be a 1-dimensional tensor
d = f(a)
d.backward()

# %%
a.grad == d/a
# Out:
# tensor(True)

# %% [markdown]
# Exercises

# %% [markdown]
# 1. Why is the second derivative much more expensive to compute than the first derivative?

# %% [markdown]
# The second derivative is much more expensive because, for a function $f$ with $n$ variables, the Hessian Matrix has $n^2$ elements while the gradient vector has $n$ elements

# %% [markdown]
# 2. After running the function for backpropagation, immediately run it again and see what happens. Why?

# %%
x.grad.zero_()
g = x
g.sum().backward().backward()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Davay\Desktop\D2L\pytorch\code\2.5 Automatic Differentiation.ipynb Cell 22 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Davay/Desktop/D2L/pytorch/code/2.5%20Automatic%20Differentiation.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> x.grad.zero_()
#       <a href='vscode-notebook-cell:/c%3A/Users/Davay/Desktop/D2L/pytorch/code/2.5%20Automatic%20Differentiation.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> g = x
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Davay/Desktop/D2L/pytorch/code/2.5%20Automatic%20Differentiation.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> g.sum().backward().backward()
#
# AttributeError: 'NoneType' object has no attribute 'backward'

# %% [markdown]
# The gradient calculation is based on the chain rule, and calling $\texttt{.backward()}$ twice would involve computing higher-order derivatives, which are not directly supported by PyTorch's autograd. The second call to $\texttt{.backward()}$ would not correctly calculate the second derivative of the objective.

# %% [markdown]
# 3. In the control flow example where we calculate the derivative of d with respect to a, what would happen if we changed the variable a to a random vector or a matrix? At this point, the result of the calculation $f(a)$ is no longer a scalar. What happens to the result? How do we analyze this?

# %%
a = torch.randn(5, requires_grad=True) 
d = f(a)
d.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\Davay\Desktop\D2L\pytorch\code\2.5 Automatic Differentiation.ipynb Cell 25 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Davay/Desktop/D2L/pytorch/code/2.5%20Automatic%20Differentiation.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> a = torch.randn(5, requires_grad=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Davay/Desktop/D2L/pytorch/code/2.5%20Automatic%20Differentiation.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> d = f(a)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Davay/Desktop/D2L/pytorch/code/2.5%20Automatic%20Differentiation.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> d.backward()
#
# File c:\Users\Davay\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File c:\Users\Davay\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\__init__.py:190, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     186 inputs = (inputs,) if isinstance(inputs, torch.Tensor) else \
#     187     tuple(inputs) if inputs is not None else tuple()
#     189 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 190 grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     191 if retain_graph is None:
#     192     retain_graph = create_graph
#
# File c:\Users\Davay\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\__init__.py:85, in _make_grads(outputs, grads, is_grads_batched)
#      83 if out.requires_grad:
#      84     if out.numel() != 1:
# ---> 85         raise RuntimeError("grad can be implicitly created only for scalar outputs")
#      86     new_grads.append(torch.ones_like(out, memory_format=torch.preserve_format))
#      87 else:
#
# RuntimeError: grad can be implicitly created only for scalar outputs

# %% [markdown]
# 4. Let $f(x) = \sin(x)$. Plot the graph of $f$ and of its derivative $f'$. Do not exploit the fact that $f'(x) = \cos(x)$
#  but rather use automatic differentiation to get the result.

# %%
from d2l import torch as d2l

# %%
def f(x): 
    return torch.sin(x)

# %%
x = torch.arange(-torch.pi,torch.pi,0.01, requires_grad=True)
y = f(x)
y.sum().backward()
d2l.plot(x.detach(), (y.detach(), x.grad), legend=('sin(x)','grad wrt x'))

# %% [markdown]
# 5. Let $f(x) = ((\log x^2) \cdot \sin x) + x^{-1}$. Write out a dependency graph tracing results from $x$ to $f(x)$.

# %% [markdown]
# 6. Use the chain rule to compute the derivative $\frac{df}{dx}$ of the aforementioned function, placing each term on the dependency graph that you constructed previously.

# %% [markdown]
# 7. Given the graph and the intermediate derivative results, you have a number of options when computing the gradient. Evaluate the result once starting from $x$ to $f$ and once from  $f$ tracing back to $x$. The path from $x$ to $f$ is commonly known as forward differentiation, whereas the path from $f$ to $x$ is known as backward differentiation.

# %% [markdown]
# 8. When might you want to use forward differentiation and when backward differentiation? Hint: consider the amount of intermediate data needed, the ability to parallelize steps, and the size of matrices and vectors involved.
